# %% [markdown]
# # ...................................................بسم الله الرحمن الرحيم..................................................

# %% [markdown]
# __In This Projet I am cleaning a dataset.__

# %% [markdown]
# __Acknowledgments:__

# %% [markdown]
# __[• eng.Mustafa Othman]("https://www.youtube.com/channel/UCITfscBBm40O9MgtqiQC00w")__

# %% [markdown]
#  __The Targeted Dataset:__ StackOverflow  - a dataset of a survey.

# %% [markdown]
# __The Objective:__ cleaning the dataset and prepare it for the data analysis.

# %% [markdown]
# # Tasks:

# %% [markdown]
# #### [1-Data Cleaning.](#1)
# <a id='5'></a>

# %% [markdown]
# #### [2-Exploring Data.](#2)
# <a id='6'></a>

# %% [markdown]
# #### [3-Checking.](#3)
# <a id='7'></a>

# %% [markdown]
# #### [4-Special Changes.](#4)
# <a id='8'></a>

# %% [markdown]
# <a id='1'></a>
# ## [1- Data Cleaning:](#5)

# %% [markdown]
# __Importing Librarys:__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px


# %matplotlib inline
sns.set()

# %% [markdown]
# __Importing Data:__

# %% [markdown]
# # بسم الله الرحمن الرحيم

# %% [markdown]
# # Importing Librarys:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import math as math
import money as money

# %matplotlib inline
sns.set()

# %% [markdown]
# # Importing Data:

# %%
so = pd.read_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-dirty.csv', parse_dates=True)

# %% [markdown]
# # Exploring Data:

# %%
so.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
so.tail()
# Out:
#          SurveyDate                                    FormalEducation  \
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 994              NaN   Yes   France                         NaN
# 995          58746.0    No    Spain                         8.0
# 996          55000.0   Yes      USA                         NaN
# 997              NaN   Yes  Sweeden                         NaN
# 998        1000000.0    No   Russia                         NaN
#
#      VersionControl  Age  Years Experience Gender     RawSalary
# 994      Subversion   45                10   Male           NaN
# ...

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   Years Experience            999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.describe()
# Out:
#        ConvertedSalary  StackOverflowJobsRecommend         Age  \
# count     6.650000e+02                  487.000000  999.000000
# mean      9.256517e+04                    7.061602   36.003003
# std       2.091344e+05                    2.621591   13.255127
# min       0.000000e+00                    0.000000   18.000000
# 25%       2.755000e+04                    5.000000   25.000000
# 50%       5.556200e+04                    7.000000   35.000000
# 75%       8.823800e+04                   10.000000   45.000000
# max       2.000000e+06                   10.000000   83.000000
#
#        Years Experience
# count        999.000000
# mean           9.961962
# std            4.878129
# min            0.000000
# 25%            7.000000
# 50%           10.000000
# 75%           13.000000
# max           27.000000

# %%
so.columns
# Out:
# Index(['SurveyDate', 'FormalEducation', 'ConvertedSalary', 'Hobby', 'Country',
#        'StackOverflowJobsRecommend', 'VersionControl', 'Age',
#        'Years Experience', 'Gender', 'RawSalary'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Columns Names:

# %%
c = so.columns

# %%
c = [i.replace(' ', '') for i in c]
c = [i.strip() for i in c]

# %%
so.set_axis(c, axis=1, inplace=True)

# %% [markdown]
# # Checking Data Types:

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.SurveyDate = pd.to_datetime(so.SurveyDate).dt.date
so.SurveyDate = pd.to_datetime(so.SurveyDate)

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    datetime64[ns]
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 86.0+ KB

# %% [markdown]
# # Checking The Outliers:

# %% [markdown]
# ## ConvertedSalary:

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France           86103.584416
# India            73894.128571
# Ireland          39873.750000
# Russia          150167.956522
# South Africa     71701.470000
# Spain            86307.470588
# Sweeden          98370.195122
# UK               59418.940299
# USA             117530.761905
# Ukraine          56292.000000
# Name: ConvertedSalary, dtype: float64

# %%
so[so['Country']=='France']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='France') & (so['ConvertedSalary']>250000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='USA']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='USA') & (so['ConvertedSalary']>1900000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='South Africa']['ConvertedSalary'].plot(kind='box', subplots= True)
# Out:
# ConvertedSalary    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
i = so[(so['Country']=='South Africa') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='India']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='India') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Russia']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Russia') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Spain']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Spain') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='UK']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='UK') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ukraine']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ukraine') & (so['ConvertedSalary']>100000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ireland']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ireland') & (so['ConvertedSalary']<20000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Sweeden']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Sweeden') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France          62842.826667
# India           56041.250000
# Ireland         53025.000000
# Russia          68887.890625
# South Africa    59374.010309
# Spain           65495.602410
# Sweeden         58561.468354
# UK              52742.681818
# USA             80977.961165
# Ukraine         45957.600000
# Name: ConvertedSalary, dtype: float64

# %% [markdown]
# # Checking The Duplicate Values:

# %%
so[so.SurveyDate.duplicated()]
# Out:
#     SurveyDate                                    FormalEducation  \
# 10  2018-05-25        Master's degree (MA. MS. M.Eng.. MBA. etc.)
# 24  2018-04-17           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 33  2018-05-25           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 45  2018-05-13           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 49  2018-02-24           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 10           47904.0   Yes    Spain                         6.0
# ...

# %% [markdown]
# #### There isn't duplicate values in this column and for the other columns the repeated values won't necessarily mean that they are duplicated.

# %% [markdown]
# # Checking and Filling Null Values:

# %% [markdown]
# ## SurveyDate:

# %%
so.SurveyDate.isna().sum()
# Out:
# 0

# %% [markdown]
# ## FormalEducation:

# %%
so.FormalEducation.value_counts()
# Out:
# Bachelor's degree (BA. BS. B.Eng.. etc.)                                              469
# Master's degree (MA. MS. M.Eng.. MBA. etc.)                                           240
# Some college/university study without earning a degree                                126
# Secondary school (e.g. American high school. German Realschule or Gymnasium. etc.)     57
# Associate degree                                                                       33
# Other doctoral degree (Ph.D. Ed.D.. etc.)                                              27
# Professional degree (JD. MD. etc.)                                                     19
# Primary/elementary school                                                               5
# I never completed any formal education                                                  1
# Name: FormalEducation, dtype: int64

# %%
so.FormalEducation.isna().sum()
# Out:
# 0

# %% [markdown]
# ## ConvertedSalary:

# %%
so.ConvertedSalary.value_counts()
# Out:
# 120000.0    10
# 130000.0     9
# 75000.0      9
# 60000.0      8
# 80000.0      7
#             ..
# 175000.0     1
# 26925.0      1
# 136500.0     1
# 37940.0      1
# 29200.0      1
# Name: ConvertedSalary, Length: 431, dtype: int64

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 334

# %%
so['NewSalary'] = so.groupby(['Country'])['ConvertedSalary'].apply(lambda x: x.fillna(x.mean()))
so['ConvertedSalary'] = so['NewSalary']
so.drop('NewSalary', axis=1, inplace=True)

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Hobby:

# %%
so.Hobby.value_counts()
# Out:
# Yes    810
# No     167
# Name: Hobby, dtype: int64

# %%
so.Hobby.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Country:

# %%
so.Country.value_counts()
# Out:
# South Africa    163
# USA             162
# Spain           132
# Sweeden         116
# France          113
# UK               94
# India            93
# Russia           92
# Ukraine           8
# Ireland           4
# Name: Country, dtype: int64

# %%
so.Country.isna().sum()
# Out:
# 0

# %% [markdown]
# ## StackOverflowJobsRecommend:

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 500

# %%
so.StackOverflowJobsRecommend.value_counts()
# Out:
# 10.0    131
# 7.0      77
# 5.0      77
# 8.0      67
# 6.0      39
# 9.0      26
# 2.0      15
# 3.0      14
# 0.0      13
# 4.0      13
# 1.0       5
# Name: StackOverflowJobsRecommend, dtype: int64

# %%
so['NewSOFJR'] = so.groupby(['Country'])['StackOverflowJobsRecommend'].apply(lambda x: x.fillna(x.mean()))
so['StackOverflowJobsRecommend'] = so['NewSOFJR']
so.drop('NewSOFJR', axis=1, inplace=True)

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 0

# %% [markdown]
# ## VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
so.VersionControl.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Age:

# %%
so.Age.value_counts()
# Out:
# 18    116
# 34     37
# 35     36
# 44     31
# 40     31
# 36     31
# 30     29
# 43     29
# 48     27
# 39     27
# 46     27
# 25     27
# 19     25
# 28     23
# 29     22
# 31     22
# 20     22
# 38     22
# 23     22
# 26     20
# 45     20
# 21     19
# 32     19
# 37     19
# 52     18
# 41     17
# 27     17
# 33     17
# 24     16
# 47     16
# 22     15
# 42     14
# 50     14
# 51     13
# 55     11
# 56     10
# 54     10
# 62      9
# 60      8
# 53      8
# 57      7
# 49      7
# 64      6
# 58      6
# 71      5
# 59      4
# 63      4
# 61      4
# 65      3
# 69      3
# 70      3
# 67      2
# 68      2
# 73      2
# 72      1
# 75      1
# 83      1
# Name: Age, dtype: int64

# %%
so.Age.isna().sum()
# Out:
# 0

# %% [markdown]
# ## YearsExperience:

# %%
so.YearsExperience.value_counts()
# Out:
# 11    80
# 8     79
# 7     75
# 10    70
# 13    67
# 12    66
# 9     63
# 14    60
# 6     56
# 15    54
# 5     49
# 4     39
# 16    32
# 17    30
# 3     26
# 18    25
# 0     25
# 1     23
# 2     19
# 19    18
# 20     6
# 21     6
# 23     5
# 22     3
# 27     1
# Name: YearsExperience, dtype: int64

# %%
so.YearsExperience.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         616
# Female                                                                        52
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Male;Non-binary. genderqueer. or gender non-conforming                         1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
so.Gender.isna().sum()
# Out:
# 301

# %%
so.Gender.fillna(method= 'ffill', inplace=True)

# %%
so.Gender.isna().sum()
# Out:
# 0

# %% [markdown]
# # Special Changes:

# %% [markdown]
# ## Handling RawSalary Column:

# %%
so.drop('RawSalary', axis=1, inplace=True)

# %%
def convertion_rate(x):     
    if x == 'USA':
        return 1
    elif x == 'France':
        return 0.9
    elif x == 'India':
        return 75.82
    elif x == 'Ireland':
        return 0.9
    elif x == 'Russia':
        return 73.52
    elif x == 'South Africa':
        return 15.3
    elif x == 'Spain':
        return 0.9
    elif x == 'Sweeden':
        return 9.08
    elif x == 'UK':
        return 0.75
    elif x == 'Ukraine':
        return 26.96

# %%
so['convertion_rate'] = so.Country.apply(lambda x: convertion_rate(x))

# %%
so['RawSalary'] = (so.ConvertedSalary * so.convertion_rate).round(2)

# %%
def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

# %%
so.RawSalary = so.RawSalary.apply(lambda x: human_format(x))

# %%
so.drop('convertion_rate', axis=1,inplace=True)

# %% [markdown]
# ## Adding ExperienceLevel Colunm:

# %%
range = [-1,3,5,10,np.inf]
Experience = ['Fresher','Junior','Senior','Expert']
so['ExperienceLevel'] = pd.cut(so['YearsExperience'],bins= range , labels= Experience)

# %% [markdown]
# ## Handling Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         899
# Female                                                                        69
# Male;Non-binary. genderqueer. or gender non-conforming                         2
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
gender_x = so[(so['Gender'] != 'Male') & (so['Gender'] != 'Female')]['Gender']
gender_x = list(gender_x)

# %%
so.Gender.replace(gender_x, 'Male', inplace=True)

# %%
so.Gender.value_counts()
# Out:
# Male      908
# Female     69
# Name: Gender, dtype: int64

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %% [markdown]
# # Rounding:

# %%
so = so.round(2)

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1   2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2   2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %% [markdown]
# # Encoding VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
x = so.VersionControl.value_counts()

# %%
x = x.index

# %%
y = []

for i in x:
    i = i.split(';')
    for n in i:
        y.append(n)

# %%
y = pd.Series(y)

# %%
y.unique()
# Out:
# array(['Git', 'Subversion', 'Team Foundation Version Control',
#        'Copying and pasting files to network shares',
#        "I don't use version control", 'Mercurial', 'Zip file back-ups'],
#       dtype=object)

# %%
so['Git'] = so['VersionControl'].str.contains('Git')
so['Git'] = so['Git'].replace(True, 1).replace(False, 0)

# %%
so['Subversion'] = so['VersionControl'].str.contains('Subversion')
so['Subversion'] = so['Subversion'].replace(True, 1).replace(False, 0)

# %%
so['TFVC'] = so['VersionControl'].str.contains('Team Foundation Version Control')
so['TFVC'] = so['TFVC'].replace(True, 1).replace(False, 0)

# %%
so['Cpftns'] = so['VersionControl'].str.contains('Copying and pasting files to network shares')
so['Cpftns'] = so['Cpftns'].replace(True, 1).replace(False, 0)

# %%
so["Doesn'tUse"] = so['VersionControl'].str.contains("I don't use version control")
so["Doesn'tUse"] = so["Doesn'tUse"].replace(True, 1).replace(False, 0)

# %%
so['Mercurial'] = so['VersionControl'].str.contains('Mercurial')
so['Mercurial'] = so['Mercurial'].replace(True, 1).replace(False, 0)

# %%
so['ZipFileBack-ups'] = so['VersionControl'].str.contains('Zip file back-ups')
so['ZipFileBack-ups'] = so['ZipFileBack-ups'].replace(True, 1).replace(False, 0)

# %% [markdown]
# # Handling FormalEducation:

# %%
so['FormalEducation'] = so.FormalEducation.apply(lambda x: x.split('(')[0].strip())

# %% [markdown]
# # Data After Cleaning:

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28                                  Bachelor's degree
# 1   2018-06-28                                  Bachelor's degree
# 2   2018-06-06                                  Bachelor's degree
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12                                  Bachelor's degree
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14                                  Bachelor's degree
# 996 2018-03-21                                  Bachelor's degree
# 997 2018-02-05                                  Bachelor's degree
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Saving The New File:

# %%
so.to_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-cleaned.csv')

# %% [markdown]
# # تمت بحمد الله

# %%
# بسم الله الرحمن الرحيم

# Importing Librarys:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import math as math
import money as money

# %matplotlib inline
sns.set()

# Importing Data:

so = pd.read_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-dirty.csv', parse_dates=True)

# Exploring Data:

so.head()

so.tail()

so.info()

so.describe()

so.columns

plt.figure(figsize=(10,10))
sns.heatmap(so.isna())

# Checking Columns Names:

c = so.columns

c = [i.replace(' ', '') for i in c]
c = [i.strip() for i in c]

so.set_axis(c, axis=1, inplace=True)

# Checking Data Types:

so.info()

so.SurveyDate = pd.to_datetime(so.SurveyDate).dt.date
so.SurveyDate = pd.to_datetime(so.SurveyDate)

so.info()

# Checking The Outliers:

## ConvertedSalary:

so.groupby(['Country']).mean()['ConvertedSalary']

so[so['Country']=='France']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='France') & (so['ConvertedSalary']>250000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='USA']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='USA') & (so['ConvertedSalary']>1900000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='South Africa']['ConvertedSalary'].plot(kind='box', subplots= True)

i = so[(so['Country']=='South Africa') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='India']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='India') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Russia']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Russia') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Spain']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Spain') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='UK']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='UK') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Ukraine']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Ukraine') & (so['ConvertedSalary']>100000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Ireland']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Ireland') & (so['ConvertedSalary']<20000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Sweeden']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Sweeden') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so.reset_index()

so.groupby(['Country']).mean()['ConvertedSalary']

# Checking The Duplicate Values:

so[so.SurveyDate.duplicated()]

#### There isn't duplicate values in this column and for the other columns the repeated values won't necessarily mean that they are duplicated.

# Checking and Filling Null Values:

## SurveyDate:

so.SurveyDate.isna().sum()

## FormalEducation:

so.FormalEducation.value_counts()

so.FormalEducation.isna().sum()

## ConvertedSalary:

so.ConvertedSalary.value_counts()

so.ConvertedSalary.isna().sum()

so['NewSalary'] = so.groupby(['Country'])['ConvertedSalary'].apply(lambda x: x.fillna(x.mean()))
so['ConvertedSalary'] = so['NewSalary']
so.drop('NewSalary', axis=1, inplace=True)

so.ConvertedSalary.isna().sum()

## Hobby:

so.Hobby.value_counts()

so.Hobby.isna().sum()

## Country:

so.Country.value_counts()

so.Country.isna().sum()

## StackOverflowJobsRecommend:

so.StackOverflowJobsRecommend.isna().sum()

so.StackOverflowJobsRecommend.value_counts()

so['NewSOFJR'] = so.groupby(['Country'])['StackOverflowJobsRecommend'].apply(lambda x: x.fillna(x.mean()))
so['StackOverflowJobsRecommend'] = so['NewSOFJR']
so.drop('NewSOFJR', axis=1, inplace=True)

so.StackOverflowJobsRecommend.isna().sum()

## VersionControl:

so.VersionControl.value_counts()

so.VersionControl.isna().sum()

## Age:

so.Age.value_counts()

so.Age.isna().sum()

## YearsExperience:

so.YearsExperience.value_counts()

so.YearsExperience.isna().sum()

## Gender:

so.Gender.value_counts()

so.Gender.isna().sum()

so.Gender.fillna(method= 'ffill', inplace=True)

so.Gender.isna().sum()

# Special Changes:

## Handling RawSalary Column:

so.drop('RawSalary', axis=1, inplace=True)

def convertion_rate(x):     
    if x == 'USA':
        return 1
    elif x == 'France':
        return 0.9
    elif x == 'India':
        return 75.82
    elif x == 'Ireland':
        return 0.9
    elif x == 'Russia':
        return 73.52
    elif x == 'South Africa':
        return 15.3
    elif x == 'Spain':
        return 0.9
    elif x == 'Sweeden':
        return 9.08
    elif x == 'UK':
        return 0.75
    elif x == 'Ukraine':
        return 26.96

so['convertion_rate'] = so.Country.apply(lambda x: convertion_rate(x))

so['RawSalary'] = (so.ConvertedSalary * so.convertion_rate).round(2)

def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

so.RawSalary = so.RawSalary.apply(lambda x: human_format(x))

so.drop('convertion_rate', axis=1,inplace=True)

## Adding ExperienceLevel Colunm:

range = [-1,3,5,10,np.inf]
Experience = ['Fresher','Junior','Senior','Expert']
so['ExperienceLevel'] = pd.cut(so['YearsExperience'],bins= range , labels= Experience)


## Handling Gender:

so.Gender.value_counts()

gender_x = so[(so['Gender'] != 'Male') & (so['Gender'] != 'Female')]['Gender']
gender_x = list(gender_x)

so.Gender.replace(gender_x, 'Male', inplace=True)

so.Gender.value_counts()

so.reset_index()

# Rounding:

so = so.round(2)

so

# Encoding VersionControl:

so.VersionControl.value_counts()

x = so.VersionControl.value_counts()

x = x.index

y = []

for i in x:
    i = i.split(';')
    for n in i:
        y.append(n)

y = pd.Series(y)

y.unique()

so['Git'] = so['VersionControl'].str.contains('Git')
so['Git'] = so['Git'].replace(True, 1).replace(False, 0)

so['Subversion'] = so['VersionControl'].str.contains('Subversion')
so['Subversion'] = so['Subversion'].replace(True, 1).replace(False, 0)

so['TFVC'] = so['VersionControl'].str.contains('Team Foundation Version Control')
so['TFVC'] = so['TFVC'].replace(True, 1).replace(False, 0)

so['Cpftns'] = so['VersionControl'].str.contains('Copying and pasting files to network shares')
so['Cpftns'] = so['Cpftns'].replace(True, 1).replace(False, 0)

so["Doesn'tUse"] = so['VersionControl'].str.contains("I don't use version control")
so["Doesn'tUse"] = so["Doesn'tUse"].replace(True, 1).replace(False, 0)

so['Mercurial'] = so['VersionControl'].str.contains('Mercurial')
so['Mercurial'] = so['Mercurial'].replace(True, 1).replace(False, 0)

so['ZipFileBack-ups'] = so['VersionControl'].str.contains('Zip file back-ups')
so['ZipFileBack-ups'] = so['ZipFileBack-ups'].replace(True, 1).replace(False, 0)

# Handling FormalEducation:

so['FormalEducation'] = so.FormalEducation.apply(lambda x: x.split('(')[0].strip())

# Data After Cleaning:

so

plt.figure(figsize=(15,10))
sns.heatmap(so.isna())

# Saving The New File:

so.to_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-cleaned.csv')

# تمت بحمد الله

# %% [markdown]
# # ...................................................بسم الله الرحمن الرحيم..................................................

# %% [markdown]
# __In This Projet I am cleaning a dataset.__

# %% [markdown]
# __Acknowledgments:__

# %% [markdown]
# __[• eng.Mustafa Othman]("https://www.youtube.com/channel/UCITfscBBm40O9MgtqiQC00w")__

# %% [markdown]
#  __The Targeted Dataset:__ kiva loans - a dataset of the organization's operations.

# %% [markdown]
# __The Objective:__ cleaning the dataset and prepare it for the data analysis.

# %% [markdown]
# # Tasks:

# %% [markdown]
# #### [1-Data Cleaning.](#1)
# <a id='5'></a>

# %% [markdown]
# #### [2-Exploring Data.](#2)
# <a id='6'></a>

# %% [markdown]
# #### [3-Checking.](#3)
# <a id='7'></a>

# %% [markdown]
# #### [4-Special Changes.](#4)
# <a id='8'></a>

# %% [markdown]
# <a id='1'></a>
# ## [1- Data Cleaning:](#5)

# %% [markdown]
# __Importing Librarys:__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px


# %matplotlib inline
sns.set()

# %% [markdown]
# __Importing Data:__

# %% [markdown]
# # بسم الله الرحمن الرحيم

# %% [markdown]
# # Importing Librarys:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import math as math
import money as money

# %matplotlib inline
sns.set()

# %% [markdown]
# # Importing Data:

# %%
so = pd.read_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-dirty.csv', parse_dates=True)

# %% [markdown]
# # Exploring Data:

# %%
so.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
so.tail()
# Out:
#          SurveyDate                                    FormalEducation  \
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 994              NaN   Yes   France                         NaN
# 995          58746.0    No    Spain                         8.0
# 996          55000.0   Yes      USA                         NaN
# 997              NaN   Yes  Sweeden                         NaN
# 998        1000000.0    No   Russia                         NaN
#
#      VersionControl  Age  Years Experience Gender     RawSalary
# 994      Subversion   45                10   Male           NaN
# ...

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   Years Experience            999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.describe()
# Out:
#        ConvertedSalary  StackOverflowJobsRecommend         Age  \
# count     6.650000e+02                  487.000000  999.000000
# mean      9.256517e+04                    7.061602   36.003003
# std       2.091344e+05                    2.621591   13.255127
# min       0.000000e+00                    0.000000   18.000000
# 25%       2.755000e+04                    5.000000   25.000000
# 50%       5.556200e+04                    7.000000   35.000000
# 75%       8.823800e+04                   10.000000   45.000000
# max       2.000000e+06                   10.000000   83.000000
#
#        Years Experience
# count        999.000000
# mean           9.961962
# std            4.878129
# min            0.000000
# 25%            7.000000
# 50%           10.000000
# 75%           13.000000
# max           27.000000

# %%
so.columns
# Out:
# Index(['SurveyDate', 'FormalEducation', 'ConvertedSalary', 'Hobby', 'Country',
#        'StackOverflowJobsRecommend', 'VersionControl', 'Age',
#        'Years Experience', 'Gender', 'RawSalary'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Columns Names:

# %%
c = so.columns

# %%
c = [i.replace(' ', '') for i in c]
c = [i.strip() for i in c]

# %%
so.set_axis(c, axis=1, inplace=True)

# %% [markdown]
# # Checking Data Types:

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.SurveyDate = pd.to_datetime(so.SurveyDate).dt.date
so.SurveyDate = pd.to_datetime(so.SurveyDate)

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    datetime64[ns]
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 86.0+ KB

# %% [markdown]
# # Checking The Outliers:

# %% [markdown]
# ## ConvertedSalary:

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France           86103.584416
# India            73894.128571
# Ireland          39873.750000
# Russia          150167.956522
# South Africa     71701.470000
# Spain            86307.470588
# Sweeden          98370.195122
# UK               59418.940299
# USA             117530.761905
# Ukraine          56292.000000
# Name: ConvertedSalary, dtype: float64

# %%
so[so['Country']=='France']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='France') & (so['ConvertedSalary']>250000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='USA']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='USA') & (so['ConvertedSalary']>1900000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='South Africa']['ConvertedSalary'].plot(kind='box', subplots= True)
# Out:
# ConvertedSalary    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
i = so[(so['Country']=='South Africa') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='India']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='India') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Russia']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Russia') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Spain']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Spain') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='UK']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='UK') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ukraine']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ukraine') & (so['ConvertedSalary']>100000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ireland']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ireland') & (so['ConvertedSalary']<20000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Sweeden']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Sweeden') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France          62842.826667
# India           56041.250000
# Ireland         53025.000000
# Russia          68887.890625
# South Africa    59374.010309
# Spain           65495.602410
# Sweeden         58561.468354
# UK              52742.681818
# USA             80977.961165
# Ukraine         45957.600000
# Name: ConvertedSalary, dtype: float64

# %% [markdown]
# # Checking The Duplicate Values:

# %%
so[so.SurveyDate.duplicated()]
# Out:
#     SurveyDate                                    FormalEducation  \
# 10  2018-05-25        Master's degree (MA. MS. M.Eng.. MBA. etc.)
# 24  2018-04-17           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 33  2018-05-25           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 45  2018-05-13           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 49  2018-02-24           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 10           47904.0   Yes    Spain                         6.0
# ...

# %% [markdown]
# #### There isn't duplicate values in this column and for the other columns the repeated values won't necessarily mean that they are duplicated.

# %% [markdown]
# # Checking and Filling Null Values:

# %% [markdown]
# ## SurveyDate:

# %%
so.SurveyDate.isna().sum()
# Out:
# 0

# %% [markdown]
# ## FormalEducation:

# %%
so.FormalEducation.value_counts()
# Out:
# Bachelor's degree (BA. BS. B.Eng.. etc.)                                              469
# Master's degree (MA. MS. M.Eng.. MBA. etc.)                                           240
# Some college/university study without earning a degree                                126
# Secondary school (e.g. American high school. German Realschule or Gymnasium. etc.)     57
# Associate degree                                                                       33
# Other doctoral degree (Ph.D. Ed.D.. etc.)                                              27
# Professional degree (JD. MD. etc.)                                                     19
# Primary/elementary school                                                               5
# I never completed any formal education                                                  1
# Name: FormalEducation, dtype: int64

# %%
so.FormalEducation.isna().sum()
# Out:
# 0

# %% [markdown]
# ## ConvertedSalary:

# %%
so.ConvertedSalary.value_counts()
# Out:
# 120000.0    10
# 130000.0     9
# 75000.0      9
# 60000.0      8
# 80000.0      7
#             ..
# 175000.0     1
# 26925.0      1
# 136500.0     1
# 37940.0      1
# 29200.0      1
# Name: ConvertedSalary, Length: 431, dtype: int64

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 334

# %%
so['NewSalary'] = so.groupby(['Country'])['ConvertedSalary'].apply(lambda x: x.fillna(x.mean()))
so['ConvertedSalary'] = so['NewSalary']
so.drop('NewSalary', axis=1, inplace=True)

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Hobby:

# %%
so.Hobby.value_counts()
# Out:
# Yes    810
# No     167
# Name: Hobby, dtype: int64

# %%
so.Hobby.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Country:

# %%
so.Country.value_counts()
# Out:
# South Africa    163
# USA             162
# Spain           132
# Sweeden         116
# France          113
# UK               94
# India            93
# Russia           92
# Ukraine           8
# Ireland           4
# Name: Country, dtype: int64

# %%
so.Country.isna().sum()
# Out:
# 0

# %% [markdown]
# ## StackOverflowJobsRecommend:

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 500

# %%
so.StackOverflowJobsRecommend.value_counts()
# Out:
# 10.0    131
# 7.0      77
# 5.0      77
# 8.0      67
# 6.0      39
# 9.0      26
# 2.0      15
# 3.0      14
# 0.0      13
# 4.0      13
# 1.0       5
# Name: StackOverflowJobsRecommend, dtype: int64

# %%
so['NewSOFJR'] = so.groupby(['Country'])['StackOverflowJobsRecommend'].apply(lambda x: x.fillna(x.mean()))
so['StackOverflowJobsRecommend'] = so['NewSOFJR']
so.drop('NewSOFJR', axis=1, inplace=True)

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 0

# %% [markdown]
# ## VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
so.VersionControl.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Age:

# %%
so.Age.value_counts()
# Out:
# 18    116
# 34     37
# 35     36
# 44     31
# 40     31
# 36     31
# 30     29
# 43     29
# 48     27
# 39     27
# 46     27
# 25     27
# 19     25
# 28     23
# 29     22
# 31     22
# 20     22
# 38     22
# 23     22
# 26     20
# 45     20
# 21     19
# 32     19
# 37     19
# 52     18
# 41     17
# 27     17
# 33     17
# 24     16
# 47     16
# 22     15
# 42     14
# 50     14
# 51     13
# 55     11
# 56     10
# 54     10
# 62      9
# 60      8
# 53      8
# 57      7
# 49      7
# 64      6
# 58      6
# 71      5
# 59      4
# 63      4
# 61      4
# 65      3
# 69      3
# 70      3
# 67      2
# 68      2
# 73      2
# 72      1
# 75      1
# 83      1
# Name: Age, dtype: int64

# %%
so.Age.isna().sum()
# Out:
# 0

# %% [markdown]
# ## YearsExperience:

# %%
so.YearsExperience.value_counts()
# Out:
# 11    80
# 8     79
# 7     75
# 10    70
# 13    67
# 12    66
# 9     63
# 14    60
# 6     56
# 15    54
# 5     49
# 4     39
# 16    32
# 17    30
# 3     26
# 18    25
# 0     25
# 1     23
# 2     19
# 19    18
# 20     6
# 21     6
# 23     5
# 22     3
# 27     1
# Name: YearsExperience, dtype: int64

# %%
so.YearsExperience.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         616
# Female                                                                        52
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Male;Non-binary. genderqueer. or gender non-conforming                         1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
so.Gender.isna().sum()
# Out:
# 301

# %%
so.Gender.fillna(method= 'ffill', inplace=True)

# %%
so.Gender.isna().sum()
# Out:
# 0

# %% [markdown]
# # Special Changes:

# %% [markdown]
# ## Handling RawSalary Column:

# %%
so.drop('RawSalary', axis=1, inplace=True)

# %%
def convertion_rate(x):     
    if x == 'USA':
        return 1
    elif x == 'France':
        return 0.9
    elif x == 'India':
        return 75.82
    elif x == 'Ireland':
        return 0.9
    elif x == 'Russia':
        return 73.52
    elif x == 'South Africa':
        return 15.3
    elif x == 'Spain':
        return 0.9
    elif x == 'Sweeden':
        return 9.08
    elif x == 'UK':
        return 0.75
    elif x == 'Ukraine':
        return 26.96

# %%
so['convertion_rate'] = so.Country.apply(lambda x: convertion_rate(x))

# %%
so['RawSalary'] = (so.ConvertedSalary * so.convertion_rate).round(2)

# %%
def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

# %%
so.RawSalary = so.RawSalary.apply(lambda x: human_format(x))

# %%
so.drop('convertion_rate', axis=1,inplace=True)

# %% [markdown]
# ## Adding ExperienceLevel Colunm:

# %%
range = [-1,3,5,10,np.inf]
Experience = ['Fresher','Junior','Senior','Expert']
so['ExperienceLevel'] = pd.cut(so['YearsExperience'],bins= range , labels= Experience)

# %% [markdown]
# ## Handling Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         899
# Female                                                                        69
# Male;Non-binary. genderqueer. or gender non-conforming                         2
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
gender_x = so[(so['Gender'] != 'Male') & (so['Gender'] != 'Female')]['Gender']
gender_x = list(gender_x)

# %%
so.Gender.replace(gender_x, 'Male', inplace=True)

# %%
so.Gender.value_counts()
# Out:
# Male      908
# Female     69
# Name: Gender, dtype: int64

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %% [markdown]
# # Rounding:

# %%
so = so.round(2)

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1   2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2   2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %% [markdown]
# # Encoding VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
x = so.VersionControl.value_counts()

# %%
x = x.index

# %%
y = []

for i in x:
    i = i.split(';')
    for n in i:
        y.append(n)

# %%
y = pd.Series(y)

# %%
y.unique()
# Out:
# array(['Git', 'Subversion', 'Team Foundation Version Control',
#        'Copying and pasting files to network shares',
#        "I don't use version control", 'Mercurial', 'Zip file back-ups'],
#       dtype=object)

# %%
so['Git'] = so['VersionControl'].str.contains('Git')
so['Git'] = so['Git'].replace(True, 1).replace(False, 0)

# %%
so['Subversion'] = so['VersionControl'].str.contains('Subversion')
so['Subversion'] = so['Subversion'].replace(True, 1).replace(False, 0)

# %%
so['TFVC'] = so['VersionControl'].str.contains('Team Foundation Version Control')
so['TFVC'] = so['TFVC'].replace(True, 1).replace(False, 0)

# %%
so['Cpftns'] = so['VersionControl'].str.contains('Copying and pasting files to network shares')
so['Cpftns'] = so['Cpftns'].replace(True, 1).replace(False, 0)

# %%
so["Doesn'tUse"] = so['VersionControl'].str.contains("I don't use version control")
so["Doesn'tUse"] = so["Doesn'tUse"].replace(True, 1).replace(False, 0)

# %%
so['Mercurial'] = so['VersionControl'].str.contains('Mercurial')
so['Mercurial'] = so['Mercurial'].replace(True, 1).replace(False, 0)

# %%
so['ZipFileBack-ups'] = so['VersionControl'].str.contains('Zip file back-ups')
so['ZipFileBack-ups'] = so['ZipFileBack-ups'].replace(True, 1).replace(False, 0)

# %% [markdown]
# # Handling FormalEducation:

# %%
so['FormalEducation'] = so.FormalEducation.apply(lambda x: x.split('(')[0].strip())

# %% [markdown]
# # Data After Cleaning:

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28                                  Bachelor's degree
# 1   2018-06-28                                  Bachelor's degree
# 2   2018-06-06                                  Bachelor's degree
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12                                  Bachelor's degree
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14                                  Bachelor's degree
# 996 2018-03-21                                  Bachelor's degree
# 997 2018-02-05                                  Bachelor's degree
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Saving The New File:

# %%
so.to_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-cleaned.csv')

# %% [markdown]
# # تمت بحمد الله

# %%
# بسم الله الرحمن الرحيم

# Importing Librarys:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import math as math
import money as money

# %matplotlib inline
sns.set()

# Importing Data:

so = pd.read_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-dirty.csv', parse_dates=True)

# Exploring Data:

so.head()

so.tail()

so.info()

so.describe()

so.columns

plt.figure(figsize=(10,10))
sns.heatmap(so.isna())

# Checking Columns Names:

c = so.columns

c = [i.replace(' ', '') for i in c]
c = [i.strip() for i in c]

so.set_axis(c, axis=1, inplace=True)

# Checking Data Types:

so.info()

so.SurveyDate = pd.to_datetime(so.SurveyDate).dt.date
so.SurveyDate = pd.to_datetime(so.SurveyDate)

so.info()

# Checking The Outliers:

## ConvertedSalary:

so.groupby(['Country']).mean()['ConvertedSalary']

so[so['Country']=='France']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='France') & (so['ConvertedSalary']>250000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='USA']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='USA') & (so['ConvertedSalary']>1900000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='South Africa']['ConvertedSalary'].plot(kind='box', subplots= True)

i = so[(so['Country']=='South Africa') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='India']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='India') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Russia']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Russia') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Spain']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Spain') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='UK']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='UK') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Ukraine']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Ukraine') & (so['ConvertedSalary']>100000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Ireland']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Ireland') & (so['ConvertedSalary']<20000)].index
so.drop(index=i, inplace=True)

so[so['Country']=='Sweeden']['ConvertedSalary'].plot(kind='box')

i = so[(so['Country']=='Sweeden') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

so.reset_index()

so.groupby(['Country']).mean()['ConvertedSalary']

# Checking The Duplicate Values:

so[so.SurveyDate.duplicated()]

#### There isn't duplicate values in this column and for the other columns the repeated values won't necessarily mean that they are duplicated.

# Checking and Filling Null Values:

## SurveyDate:

so.SurveyDate.isna().sum()

## FormalEducation:

so.FormalEducation.value_counts()

so.FormalEducation.isna().sum()

## ConvertedSalary:

so.ConvertedSalary.value_counts()

so.ConvertedSalary.isna().sum()

so['NewSalary'] = so.groupby(['Country'])['ConvertedSalary'].apply(lambda x: x.fillna(x.mean()))
so['ConvertedSalary'] = so['NewSalary']
so.drop('NewSalary', axis=1, inplace=True)

so.ConvertedSalary.isna().sum()

## Hobby:

so.Hobby.value_counts()

so.Hobby.isna().sum()

## Country:

so.Country.value_counts()

so.Country.isna().sum()

## StackOverflowJobsRecommend:

so.StackOverflowJobsRecommend.isna().sum()

so.StackOverflowJobsRecommend.value_counts()

so['NewSOFJR'] = so.groupby(['Country'])['StackOverflowJobsRecommend'].apply(lambda x: x.fillna(x.mean()))
so['StackOverflowJobsRecommend'] = so['NewSOFJR']
so.drop('NewSOFJR', axis=1, inplace=True)

so.StackOverflowJobsRecommend.isna().sum()

## VersionControl:

so.VersionControl.value_counts()

so.VersionControl.isna().sum()

## Age:

so.Age.value_counts()

so.Age.isna().sum()

## YearsExperience:

so.YearsExperience.value_counts()

so.YearsExperience.isna().sum()

## Gender:

so.Gender.value_counts()

so.Gender.isna().sum()

so.Gender.fillna(method= 'ffill', inplace=True)

so.Gender.isna().sum()

# Special Changes:

## Handling RawSalary Column:

so.drop('RawSalary', axis=1, inplace=True)

def convertion_rate(x):     
    if x == 'USA':
        return 1
    elif x == 'France':
        return 0.9
    elif x == 'India':
        return 75.82
    elif x == 'Ireland':
        return 0.9
    elif x == 'Russia':
        return 73.52
    elif x == 'South Africa':
        return 15.3
    elif x == 'Spain':
        return 0.9
    elif x == 'Sweeden':
        return 9.08
    elif x == 'UK':
        return 0.75
    elif x == 'Ukraine':
        return 26.96

so['convertion_rate'] = so.Country.apply(lambda x: convertion_rate(x))

so['RawSalary'] = (so.ConvertedSalary * so.convertion_rate).round(2)

def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

so.RawSalary = so.RawSalary.apply(lambda x: human_format(x))

so.drop('convertion_rate', axis=1,inplace=True)

## Adding ExperienceLevel Colunm:

range = [-1,3,5,10,np.inf]
Experience = ['Fresher','Junior','Senior','Expert']
so['ExperienceLevel'] = pd.cut(so['YearsExperience'],bins= range , labels= Experience)


## Handling Gender:

so.Gender.value_counts()

gender_x = so[(so['Gender'] != 'Male') & (so['Gender'] != 'Female')]['Gender']
gender_x = list(gender_x)

so.Gender.replace(gender_x, 'Male', inplace=True)

so.Gender.value_counts()

so.reset_index()

# Rounding:

so = so.round(2)

so

# Encoding VersionControl:

so.VersionControl.value_counts()

x = so.VersionControl.value_counts()

x = x.index

y = []

for i in x:
    i = i.split(';')
    for n in i:
        y.append(n)

y = pd.Series(y)

y.unique()

so['Git'] = so['VersionControl'].str.contains('Git')
so['Git'] = so['Git'].replace(True, 1).replace(False, 0)

so['Subversion'] = so['VersionControl'].str.contains('Subversion')
so['Subversion'] = so['Subversion'].replace(True, 1).replace(False, 0)

so['TFVC'] = so['VersionControl'].str.contains('Team Foundation Version Control')
so['TFVC'] = so['TFVC'].replace(True, 1).replace(False, 0)

so['Cpftns'] = so['VersionControl'].str.contains('Copying and pasting files to network shares')
so['Cpftns'] = so['Cpftns'].replace(True, 1).replace(False, 0)

so["Doesn'tUse"] = so['VersionControl'].str.contains("I don't use version control")
so["Doesn'tUse"] = so["Doesn'tUse"].replace(True, 1).replace(False, 0)

so['Mercurial'] = so['VersionControl'].str.contains('Mercurial')
so['Mercurial'] = so['Mercurial'].replace(True, 1).replace(False, 0)

so['ZipFileBack-ups'] = so['VersionControl'].str.contains('Zip file back-ups')
so['ZipFileBack-ups'] = so['ZipFileBack-ups'].replace(True, 1).replace(False, 0)

# Handling FormalEducation:

so['FormalEducation'] = so.FormalEducation.apply(lambda x: x.split('(')[0].strip())

# Data After Cleaning:

so

plt.figure(figsize=(15,10))
sns.heatmap(so.isna())

# Saving The New File:

so.to_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-cleaned.csv')

# تمت بحمد الله

# %% [markdown]
# # ...................................................بسم الله الرحمن الرحيم..................................................

# %% [markdown]
# __In This Projet I am cleaning a dataset.__

# %% [markdown]
# __Acknowledgments:__

# %% [markdown]
# __[• eng.Mustafa Othman]("https://www.youtube.com/channel/UCITfscBBm40O9MgtqiQC00w")__

# %% [markdown]
#  __The Targeted Dataset:__ kiva loans - a dataset of the organization's operations.

# %% [markdown]
# __The Objective:__ cleaning the dataset and prepare it for the data analysis.

# %% [markdown]
# # بسم الله الرحمن الرحيم

# %% [markdown]
# # Importing Librarys:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import math as math
import money as money

# %matplotlib inline
sns.set()

# %% [markdown]
# # Importing Data:

# %%
so = pd.read_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-dirty.csv', parse_dates=True)

# %% [markdown]
# # Exploring Data:

# %%
so.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
so.tail()
# Out:
#          SurveyDate                                    FormalEducation  \
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 994              NaN   Yes   France                         NaN
# 995          58746.0    No    Spain                         8.0
# 996          55000.0   Yes      USA                         NaN
# 997              NaN   Yes  Sweeden                         NaN
# 998        1000000.0    No   Russia                         NaN
#
#      VersionControl  Age  Years Experience Gender     RawSalary
# 994      Subversion   45                10   Male           NaN
# ...

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   Years Experience            999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.describe()
# Out:
#        ConvertedSalary  StackOverflowJobsRecommend         Age  \
# count     6.650000e+02                  487.000000  999.000000
# mean      9.256517e+04                    7.061602   36.003003
# std       2.091344e+05                    2.621591   13.255127
# min       0.000000e+00                    0.000000   18.000000
# 25%       2.755000e+04                    5.000000   25.000000
# 50%       5.556200e+04                    7.000000   35.000000
# 75%       8.823800e+04                   10.000000   45.000000
# max       2.000000e+06                   10.000000   83.000000
#
#        Years Experience
# count        999.000000
# mean           9.961962
# std            4.878129
# min            0.000000
# 25%            7.000000
# 50%           10.000000
# 75%           13.000000
# max           27.000000

# %%
so.columns
# Out:
# Index(['SurveyDate', 'FormalEducation', 'ConvertedSalary', 'Hobby', 'Country',
#        'StackOverflowJobsRecommend', 'VersionControl', 'Age',
#        'Years Experience', 'Gender', 'RawSalary'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Columns Names:

# %%
c = so.columns

# %%
c = [i.replace(' ', '') for i in c]
c = [i.strip() for i in c]

# %%
so.set_axis(c, axis=1, inplace=True)

# %% [markdown]
# # Checking Data Types:

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB

# %%
so.SurveyDate = pd.to_datetime(so.SurveyDate).dt.date
so.SurveyDate = pd.to_datetime(so.SurveyDate)

# %%
so.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    datetime64[ns]
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   YearsExperience             999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 86.0+ KB

# %% [markdown]
# # Checking The Outliers:

# %% [markdown]
# ## ConvertedSalary:

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France           86103.584416
# India            73894.128571
# Ireland          39873.750000
# Russia          150167.956522
# South Africa     71701.470000
# Spain            86307.470588
# Sweeden          98370.195122
# UK               59418.940299
# USA             117530.761905
# Ukraine          56292.000000
# Name: ConvertedSalary, dtype: float64

# %%
so[so['Country']=='France']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='France') & (so['ConvertedSalary']>250000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='USA']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='USA') & (so['ConvertedSalary']>1900000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='South Africa']['ConvertedSalary'].plot(kind='box', subplots= True)
# Out:
# ConvertedSalary    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
i = so[(so['Country']=='South Africa') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='India']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='India') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Russia']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Russia') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Spain']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Spain') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='UK']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='UK') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ukraine']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ukraine') & (so['ConvertedSalary']>100000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Ireland']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Ireland') & (so['ConvertedSalary']<20000)].index
so.drop(index=i, inplace=True)

# %%
so[so['Country']=='Sweeden']['ConvertedSalary'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
i = so[(so['Country']=='Sweeden') & (so['ConvertedSalary']>200000)].index
so.drop(index=i, inplace=True)

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
so.groupby(['Country']).mean()['ConvertedSalary']
# Out:
# Country
# France          62842.826667
# India           56041.250000
# Ireland         53025.000000
# Russia          68887.890625
# South Africa    59374.010309
# Spain           65495.602410
# Sweeden         58561.468354
# UK              52742.681818
# USA             80977.961165
# Ukraine         45957.600000
# Name: ConvertedSalary, dtype: float64

# %% [markdown]
# # Checking The Duplicate Values:

# %%
so[so.SurveyDate.duplicated()]
# Out:
#     SurveyDate                                    FormalEducation  \
# 10  2018-05-25        Master's degree (MA. MS. M.Eng.. MBA. etc.)
# 24  2018-04-17           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 33  2018-05-25           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 45  2018-05-13           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 49  2018-02-24           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby  Country  StackOverflowJobsRecommend  \
# 10           47904.0   Yes    Spain                         6.0
# ...

# %% [markdown]
# #### There isn't duplicate values in this column and for the other columns the repeated values won't necessarily mean that they are duplicated.

# %% [markdown]
# # Checking and Filling Null Values:

# %% [markdown]
# ## SurveyDate:

# %%
so.SurveyDate.isna().sum()
# Out:
# 0

# %% [markdown]
# ## FormalEducation:

# %%
so.FormalEducation.value_counts()
# Out:
# Bachelor's degree (BA. BS. B.Eng.. etc.)                                              469
# Master's degree (MA. MS. M.Eng.. MBA. etc.)                                           240
# Some college/university study without earning a degree                                126
# Secondary school (e.g. American high school. German Realschule or Gymnasium. etc.)     57
# Associate degree                                                                       33
# Other doctoral degree (Ph.D. Ed.D.. etc.)                                              27
# Professional degree (JD. MD. etc.)                                                     19
# Primary/elementary school                                                               5
# I never completed any formal education                                                  1
# Name: FormalEducation, dtype: int64

# %%
so.FormalEducation.isna().sum()
# Out:
# 0

# %% [markdown]
# ## ConvertedSalary:

# %%
so.ConvertedSalary.value_counts()
# Out:
# 120000.0    10
# 130000.0     9
# 75000.0      9
# 60000.0      8
# 80000.0      7
#             ..
# 175000.0     1
# 26925.0      1
# 136500.0     1
# 37940.0      1
# 29200.0      1
# Name: ConvertedSalary, Length: 431, dtype: int64

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 334

# %%
so['NewSalary'] = so.groupby(['Country'])['ConvertedSalary'].apply(lambda x: x.fillna(x.mean()))
so['ConvertedSalary'] = so['NewSalary']
so.drop('NewSalary', axis=1, inplace=True)

# %%
so.ConvertedSalary.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Hobby:

# %%
so.Hobby.value_counts()
# Out:
# Yes    810
# No     167
# Name: Hobby, dtype: int64

# %%
so.Hobby.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Country:

# %%
so.Country.value_counts()
# Out:
# South Africa    163
# USA             162
# Spain           132
# Sweeden         116
# France          113
# UK               94
# India            93
# Russia           92
# Ukraine           8
# Ireland           4
# Name: Country, dtype: int64

# %%
so.Country.isna().sum()
# Out:
# 0

# %% [markdown]
# ## StackOverflowJobsRecommend:

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 500

# %%
so.StackOverflowJobsRecommend.value_counts()
# Out:
# 10.0    131
# 7.0      77
# 5.0      77
# 8.0      67
# 6.0      39
# 9.0      26
# 2.0      15
# 3.0      14
# 0.0      13
# 4.0      13
# 1.0       5
# Name: StackOverflowJobsRecommend, dtype: int64

# %%
so['NewSOFJR'] = so.groupby(['Country'])['StackOverflowJobsRecommend'].apply(lambda x: x.fillna(x.mean()))
so['StackOverflowJobsRecommend'] = so['NewSOFJR']
so.drop('NewSOFJR', axis=1, inplace=True)

# %%
so.StackOverflowJobsRecommend.isna().sum()
# Out:
# 0

# %% [markdown]
# ## VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
so.VersionControl.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Age:

# %%
so.Age.value_counts()
# Out:
# 18    116
# 34     37
# 35     36
# 44     31
# 40     31
# 36     31
# 30     29
# 43     29
# 48     27
# 39     27
# 46     27
# 25     27
# 19     25
# 28     23
# 29     22
# 31     22
# 20     22
# 38     22
# 23     22
# 26     20
# 45     20
# 21     19
# 32     19
# 37     19
# 52     18
# 41     17
# 27     17
# 33     17
# 24     16
# 47     16
# 22     15
# 42     14
# 50     14
# 51     13
# 55     11
# 56     10
# 54     10
# 62      9
# 60      8
# 53      8
# 57      7
# 49      7
# 64      6
# 58      6
# 71      5
# 59      4
# 63      4
# 61      4
# 65      3
# 69      3
# 70      3
# 67      2
# 68      2
# 73      2
# 72      1
# 75      1
# 83      1
# Name: Age, dtype: int64

# %%
so.Age.isna().sum()
# Out:
# 0

# %% [markdown]
# ## YearsExperience:

# %%
so.YearsExperience.value_counts()
# Out:
# 11    80
# 8     79
# 7     75
# 10    70
# 13    67
# 12    66
# 9     63
# 14    60
# 6     56
# 15    54
# 5     49
# 4     39
# 16    32
# 17    30
# 3     26
# 18    25
# 0     25
# 1     23
# 2     19
# 19    18
# 20     6
# 21     6
# 23     5
# 22     3
# 27     1
# Name: YearsExperience, dtype: int64

# %%
so.YearsExperience.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         616
# Female                                                                        52
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Male;Non-binary. genderqueer. or gender non-conforming                         1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
so.Gender.isna().sum()
# Out:
# 301

# %%
so.Gender.fillna(method= 'ffill', inplace=True)

# %%
so.Gender.isna().sum()
# Out:
# 0

# %% [markdown]
# # Special Changes:

# %% [markdown]
# ## Handling RawSalary Column:

# %%
so.drop('RawSalary', axis=1, inplace=True)

# %%
def convertion_rate(x):     
    if x == 'USA':
        return 1
    elif x == 'France':
        return 0.9
    elif x == 'India':
        return 75.82
    elif x == 'Ireland':
        return 0.9
    elif x == 'Russia':
        return 73.52
    elif x == 'South Africa':
        return 15.3
    elif x == 'Spain':
        return 0.9
    elif x == 'Sweeden':
        return 9.08
    elif x == 'UK':
        return 0.75
    elif x == 'Ukraine':
        return 26.96

# %%
so['convertion_rate'] = so.Country.apply(lambda x: convertion_rate(x))

# %%
so['RawSalary'] = (so.ConvertedSalary * so.convertion_rate).round(2)

# %%
def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

# %%
so.RawSalary = so.RawSalary.apply(lambda x: human_format(x))

# %%
so.drop('convertion_rate', axis=1,inplace=True)

# %% [markdown]
# ## Adding ExperienceLevel Colunm:

# %%
range = [-1,3,5,10,np.inf]
Experience = ['Fresher','Junior','Senior','Expert']
so['ExperienceLevel'] = pd.cut(so['YearsExperience'],bins= range , labels= Experience)

# %% [markdown]
# ## Handling Gender:

# %%
so.Gender.value_counts()
# Out:
# Male                                                                         899
# Female                                                                        69
# Male;Non-binary. genderqueer. or gender non-conforming                         2
# Transgender                                                                    2
# Female;Male                                                                    2
# Female;Male;Transgender;Non-binary. genderqueer. or gender non-conforming      1
# Female;Transgender                                                             1
# Non-binary. genderqueer. or gender non-conforming                              1
# Name: Gender, dtype: int64

# %%
gender_x = so[(so['Gender'] != 'Male') & (so['Gender'] != 'Female')]['Gender']
gender_x = list(gender_x)

# %%
so.Gender.replace(gender_x, 'Male', inplace=True)

# %%
so.Gender.value_counts()
# Out:
# Male      908
# Female     69
# Name: Gender, dtype: int64

# %%
so.reset_index()
# Out:
#      index SurveyDate                                    FormalEducation  \
# 0        0 2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1        1 2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2        2 2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3        3 2018-05-09  Some college/university study without earning ...
# 4        4 2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..     ...        ...                                                ...
# 972    993 2018-03-04  Some college/university study without earning ...
# 973    994 2018-10-19  Some college/university study without earning ...
# 974    995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 975    996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 976    997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %% [markdown]
# # Rounding:

# %%
so = so.round(2)

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1   2018-06-28           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2   2018-06-06           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996 2018-03-21           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997 2018-02-05           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %% [markdown]
# # Encoding VersionControl:

# %%
so.VersionControl.value_counts()
# Out:
# Git                                                                                                             563
# Git;Subversion                                                                                                   95
# Git;Team Foundation Version Control                                                                              62
# Subversion                                                                                                       36
# Team Foundation Version Control                                                                                  27
# Git;Copying and pasting files to network shares                                                                  22
# I don't use version control                                                                                      22
# Git;Mercurial                                                                                                    22
# ...

# %%
x = so.VersionControl.value_counts()

# %%
x = x.index

# %%
y = []

for i in x:
    i = i.split(';')
    for n in i:
        y.append(n)

# %%
y = pd.Series(y)

# %%
y.unique()
# Out:
# array(['Git', 'Subversion', 'Team Foundation Version Control',
#        'Copying and pasting files to network shares',
#        "I don't use version control", 'Mercurial', 'Zip file back-ups'],
#       dtype=object)

# %%
so['Git'] = so['VersionControl'].str.contains('Git')
so['Git'] = so['Git'].replace(True, 1).replace(False, 0)

# %%
so['Subversion'] = so['VersionControl'].str.contains('Subversion')
so['Subversion'] = so['Subversion'].replace(True, 1).replace(False, 0)

# %%
so['TFVC'] = so['VersionControl'].str.contains('Team Foundation Version Control')
so['TFVC'] = so['TFVC'].replace(True, 1).replace(False, 0)

# %%
so['Cpftns'] = so['VersionControl'].str.contains('Copying and pasting files to network shares')
so['Cpftns'] = so['Cpftns'].replace(True, 1).replace(False, 0)

# %%
so["Doesn'tUse"] = so['VersionControl'].str.contains("I don't use version control")
so["Doesn'tUse"] = so["Doesn'tUse"].replace(True, 1).replace(False, 0)

# %%
so['Mercurial'] = so['VersionControl'].str.contains('Mercurial')
so['Mercurial'] = so['Mercurial'].replace(True, 1).replace(False, 0)

# %%
so['ZipFileBack-ups'] = so['VersionControl'].str.contains('Zip file back-ups')
so['ZipFileBack-ups'] = so['ZipFileBack-ups'].replace(True, 1).replace(False, 0)

# %% [markdown]
# # Handling FormalEducation:

# %%
so['FormalEducation'] = so.FormalEducation.apply(lambda x: x.split('(')[0].strip())

# %% [markdown]
# # Data After Cleaning:

# %%
so
# Out:
#     SurveyDate                                    FormalEducation  \
# 0   2018-02-28                                  Bachelor's degree
# 1   2018-06-28                                  Bachelor's degree
# 2   2018-06-06                                  Bachelor's degree
# 3   2018-05-09  Some college/university study without earning ...
# 4   2018-04-12                                  Bachelor's degree
# ..         ...                                                ...
# 993 2018-03-04  Some college/university study without earning ...
# 994 2018-10-19  Some college/university study without earning ...
# 995 2018-04-14                                  Bachelor's degree
# 996 2018-03-21                                  Bachelor's degree
# 997 2018-02-05                                  Bachelor's degree
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0           59374.01   Yes  South Africa                        6.80
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(so.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Saving The New File:

# %%
so.to_csv('Desktop/Data-science/Python-Data-Analysis-Diploma/Data_sets_for_PDA_diploma/stackoverflow-cleaned.csv')

# %% [markdown]
# # تمت بحمد الله
