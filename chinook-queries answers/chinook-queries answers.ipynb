# %% [markdown]
# #                                            بسم الله الرحمن الرحيم

# %% [markdown]
# # Importing Librarys:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import re
import sys 

# %matplotlib inline
sns.set()

# %% [markdown]
# # Importing Data:

# %%
sys.path = []
sys.path.append('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook')
sys.path.append('')

# %%
album = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/album.csv')
artist = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/artist.csv')
customer = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/customer.csv')
employee = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/employee.csv')
genre = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/genre.csv')
invoiceline = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/invoice-line.csv')
invoice = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/invoice.csv')
mediatype = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/media-type.csv')
playlisttrack = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/playlist-track.csv')
playlist = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/playlist.csv')
track = pd.read_csv('C:/Users/dramr/Desktop/Data-science/Python-Data-Analysis-Diploma/preprocessing-materials/datasets/chinook/track.csv')

# %%
chinook = {'album': album,
           'artist': artist,
           'customer': customer,
           'employee': employee,
           'genre': genre,
           'invoiceline': invoiceline,
           'invoice': invoice,
           'mediatype': mediatype,
           'playlisttrack': playlisttrack,
           'playlist': playlist,
           'track': track}
chinook = pd.Series(chinook)

# %% [markdown]
# ### 1. Provide a query showing Customers (just their full names, customer ID and country) who are not in the US.

# %%
chinook.customer[chinook.customer['Country'] != 'USA'][['FirstName', 'LastName', 'CustomerId', 'Country']]
# Out:
#     FirstName      LastName  CustomerId         Country
# 0        Luís     Gonçalves           1          Brazil
# 1      Leonie        Köhler           2         Germany
# 2    François      Tremblay           3          Canada
# 3       Bjørn        Hansen           4          Norway
# 4   František   Wichterlová           5  Czech Republic
# 5      Helena          Holý           6  Czech Republic
# 6      Astrid        Gruber           7         Austria
# 7        Daan       Peeters           8         Belgium
# 8        Kara       Nielsen           9         Denmark
# 9     Eduardo       Martins          10          Brazil
# 10  Alexandre         Rocha          11          Brazil
# 11    Roberto       Almeida          12          Brazil
# 12   Fernanda         Ramos          13          Brazil
# 13       Mark       Philips          14          Canada
# 14   Jennifer      Peterson          15          Canada
# 28     Robert         Brown          29          Canada
# ...

# %% [markdown]
# ### 2. Provide a query only showing the Customers from Brazil.

# %%
chinook.customer[chinook.customer['Country'] == 'Brazil']
# Out:
#     CustomerId  FirstName   LastName  \
# 0            1       Luís  Gonçalves
# 9           10    Eduardo    Martins
# 10          11  Alexandre      Rocha
# 11          12    Roberto    Almeida
# 12          13   Fernanda      Ramos
#
#                                              Company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 12                                               ---
#
#                             Address                 City State Country  \
# 0   Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 9         Rua Dr. Falcão Filho, 155            São Paulo    SP  Brazil
# 10               Av. Paulista, 2022            São Paulo    SP  Brazil
# 11                 Praça Pio X, 119       Rio de Janeiro    RJ  Brazil
# ...

# %% [markdown]
# ### 3. Provide a query showing the Invoices of customers who are from Brazil. The resultant table should show the customer's full name.

# %%
x_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')
x_df[x_df['Country'] == 'Brazil'][['FirstName', 'LastName']].drop_duplicates().reset_index(drop=True)
# Out:
#    FirstName   LastName
# 0       Luís  Gonçalves
# 1    Eduardo    Martins
# 2  Alexandre      Rocha
# 3    Roberto    Almeida
# 4   Fernanda      Ramos

# %% [markdown]
# ### 4. Provide a query showing only the Employees who are Sales Agents.

# %%
chinook.employee[chinook.employee['Title'] == 'Sales Support Agent'].reset_index(drop=True)
# Out:
#    EmployeeId LastName FirstName                Title ReportsTo   BirthDate  \
# 0           3  Peacock      Jane  Sales Support Agent         2  1973-08-29
# 1           4     Park  Margaret  Sales Support Agent         2  1947-09-19
# 2           5  Johnson     Steve  Sales Support Agent         2  1965-03-03
#
#      HireDate           Address     City State Country PostalCode  \
# 0  2002-04-01     1111 6 Ave SW  Calgary    AB  Canada    T2P 5M5
# 1  2003-05-03  683 10 Street SW  Calgary    AB  Canada    T2P 5G3
# 2  2003-10-17      7727B 41 Ave  Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# 0  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 1  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 2   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# ### 5. Provide a query showing a unique list of billing countries from the Invoice table.

# %%
list(chinook.invoice['BillingCountry'].unique())
# Out:
# ['Germany',
#  'Norway',
#  'Belgium',
#  'Canada',
#  'USA',
#  'France',
#  'Ireland',
#  'United Kingdom',
#  'Australia',
#  'Chile',
#  'India',
#  'Brazil',
#  'Portugal',
#  'Netherlands',
#  'Spain',
#  'Sweden',
#  'Czech Republic',
#  'Finland',
#  'Denmark',
#  'Italy',
#  'Poland',
#  'Austria',
#  'Hungary',
#  'Argentina']

# %% [markdown]
# ### 6. Provide a query showing the invoices of customers who are from Brazil.

# %%
x_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')
x_df[x_df['Country'] == 'Brazil'].reset_index(drop=True)
# Out:
#     CustomerId  FirstName   LastName  \
# 0            1       Luís  Gonçalves
# 1            1       Luís  Gonçalves
# 2            1       Luís  Gonçalves
# 3            1       Luís  Gonçalves
# 4            1       Luís  Gonçalves
# 5            1       Luís  Gonçalves
# 6            1       Luís  Gonçalves
# 7           10    Eduardo    Martins
# 8           10    Eduardo    Martins
# 9           10    Eduardo    Martins
# 10          10    Eduardo    Martins
# 11          10    Eduardo    Martins
# 12          10    Eduardo    Martins
# 13          10    Eduardo    Martins
# 14          11  Alexandre      Rocha
# 15          11  Alexandre      Rocha
# 16          11  Alexandre      Rocha
# 17          11  Alexandre      Rocha
# 18          11  Alexandre      Rocha
# 19          11  Alexandre      Rocha
# 20          11  Alexandre      Rocha
# 21          12    Roberto    Almeida
# 22          12    Roberto    Almeida
# 23          12    Roberto    Almeida
# ...

# %% [markdown]
# ### 7. Provide a query that shows the invoices associated with each sales agent. The resultant table should include the Sales Agent's full name.

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
chinook.employee.merge(ic_df, left_on='EmployeeId', right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Customer'))[['LastName_Employee', 'FirstName_Employee']].drop_duplicates().reset_index(drop=True)
# Out:
#   LastName_Employee FirstName_Employee
# 0           Peacock               Jane
# 1              Park           Margaret
# 2           Johnson              Steve

# %% [markdown]
# ### 8. Provide a query that shows the Invoice Total, Customer name, Country and Sale Agent name for all invoices and customers.

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
ic_df.merge(chinook.employee, left_on='SupportRepId', right_on='EmployeeId', how='inner', suffixes=('_Customer','_Employee'))[['Total', 'FirstName_Customer', 'LastName_Customer', 'Country_Customer', 'FirstName_Employee', 'LastName_Employee']]
# Out:
#      Total FirstName_Customer LastName_Customer Country_Customer  \
# 0     3.98               Luís         Gonçalves           Brazil
# 1     3.96               Luís         Gonçalves           Brazil
# 2     5.94               Luís         Gonçalves           Brazil
# 3     0.99               Luís         Gonçalves           Brazil
# 4     1.98               Luís         Gonçalves           Brazil
# ..     ...                ...               ...              ...
# 407   5.94              Diego         Gutiérrez        Argentina
# 408   0.99              Diego         Gutiérrez        Argentina
# 409   1.98              Diego         Gutiérrez        Argentina
# 410  13.86              Diego         Gutiérrez        Argentina
# 411   8.91              Diego         Gutiérrez        Argentina
#
#     FirstName_Employee LastName_Employee
# 0                 Jane           Peacock
# 1                 Jane           Peacock
# 2                 Jane           Peacock
# ...

# %% [markdown]
# ### 9. How many Invoices were there in 2009 and 2011? What are the respective total sales for each of those years?

# %%
chinook.invoice['counter'] = 1
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
x_df = chinook.invoice.groupby('InvoiceYear').sum()
x_df.loc[[2009, 2011]][['Total', 'counter']]
# Out:
#               Total  counter
# InvoiceYear
# 2009         449.46       83
# 2011         469.58       83

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)
chinook.invoice.drop('counter', axis=1, inplace=True)

# %% [markdown]
# ### 10. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for Invoice ID 37.

# %%
chinook.invoiceline[chinook.invoiceline['InvoiceId'] == 37]['InvoiceLineId'].count()
# Out:
# 4

# %% [markdown]
# ### 11. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for each Invoice.

# %%
pd.DataFrame(chinook.invoiceline.groupby('InvoiceId')['InvoiceLineId'].count())
# Out:
#            InvoiceLineId
# InvoiceId
# 1                      2
# 2                      4
# 3                      6
# 4                      9
# 5                     14
# ...                  ...
# 408                    4
# 409                    6
# 410                    9
# 411                   14
# 412                    1
#
# [412 rows x 1 columns]

# %% [markdown]
# ### 12. Provide a query that includes the track name with each invoice line item.

# %%
chinook.track.merge(chinook.invoiceline, on='TrackId', how='inner', suffixes=('_Track', '_InvoiceLine'))[['InvoiceLineId', 'InvoiceId', 'TrackId', 'UnitPrice_InvoiceLine', 'Quantity', 'Name']]
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice_InvoiceLine  Quantity  \
# 0               579        108        1                   0.99         1
# 1                 1          1        2                   0.99         1
# 2              1154        214        2                   0.99         1
# 3              1728        319        3                   0.99         1
# 4                 2          1        4                   0.99         1
# ...             ...        ...      ...                    ...       ...
# 2235           1726        319     3494                   0.99         1
# 2236            577        108     3496                   0.99         1
# 2237           1153        214     3499                   0.99         1
# 2238            578        108     3500                   0.99         1
# 2239           1727        319     3500                   0.99         1
#
#                                                    Name
# ...

# %% [markdown]
# ### 13. Provide a query that includes the purchased track name AND artist name with each invoice line item.

# %%
x_df = chinook.album.merge(chinook.artist, on='ArtistId', how='inner')
x_df = x_df[['AlbumId', 'Name']]

# %%
chinook.track.merge(chinook.invoiceline, on='TrackId', how='inner', suffixes=('_Track', '_InvoiceLine')).merge(x_df, on='AlbumId', how='inner', suffixes=('_Track', '_Artist'))[['InvoiceLineId', 'InvoiceId', 'TrackId', 'UnitPrice_InvoiceLine', 'Quantity', 'Name_Track', 'Name_Artist']]
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice_InvoiceLine  Quantity  \
# 0               579        108        1                   0.99         1
# 1                 3          2        6                   0.99         1
# 2                 4          2        8                   0.99         1
# 3              1155        214        8                   0.99         1
# 4               581        108        9                   0.99         1
# ...             ...        ...      ...                    ...       ...
# 2235           1726        319     3494                   0.99         1
# 2236            577        108     3496                   0.99         1
# 2237           1153        214     3499                   0.99         1
# 2238            578        108     3500                   0.99         1
# 2239           1727        319     3500                   0.99         1
#
#                                              Name_Track  \
# ...

# %% [markdown]
# ### 14. Provide a query that shows the # of invoices per country.

# %%
pd.DataFrame(chinook.invoice.groupby('BillingCountry')['InvoiceId'].count()).sort_values(ascending=False, by='InvoiceId')
# Out:
#                 InvoiceId
# BillingCountry
# USA                    91
# Canada                 56
# Brazil                 35
# France                 35
# Germany                28
# United Kingdom         21
# Czech Republic         14
# Portugal               14
# India                  13
# Italy                   7
# Sweden                  7
# Spain                   7
# Poland                  7
# Norway                  7
# Netherlands             7
# Argentina               7
# Ireland                 7
# Australia               7
# Finland                 7
# Denmark                 7
# Chile                   7
# Belgium                 7
# Austria                 7
# Hungary                 7

# %%
# حل مبسط 
pd.DataFrame(chinook.invoice.BillingCountry.value_counts())
# Out:
#                 BillingCountry
# USA                         91
# Canada                      56
# France                      35
# Brazil                      35
# Germany                     28
# United Kingdom              21
# Czech Republic              14
# Portugal                    14
# India                       13
# Spain                        7
# Finland                      7
# Sweden                       7
# Italy                        7
# Chile                        7
# Netherlands                  7
# Belgium                      7
# Denmark                      7
# Australia                    7
# Ireland                      7
# Norway                       7
# Poland                       7
# Austria                      7
# Hungary                      7
# Argentina                    7

# %% [markdown]
# ### 15. Provide a query that shows the total number of tracks in each playlist. The Playlist name should be include on the resultant table.

# %%
x_df = chinook.playlist.merge(chinook.playlisttrack, on='PlaylistId', how='inner')
x_df
# Out:
#       PlaylistId                 Name  TrackId
# 0              1                Music     3402
# 1              1                Music     3389
# 2              1                Music     3390
# 3              1                Music     3391
# 4              1                Music     3392
# ...          ...                  ...      ...
# 8710          17  Heavy Metal Classic     2094
# 8711          17  Heavy Metal Classic     2095
# 8712          17  Heavy Metal Classic     2096
# 8713          17  Heavy Metal Classic     3290
# 8714          18          On-The-Go 1      597
#
# [8715 rows x 3 columns]

# %%
pd.DataFrame(chinook.track.merge(x_df, on='TrackId', how='inner', suffixes=('_Track', '_PlayList')).groupby('Name_PlayList')['Name_Track'].count())
# Out:
#                             Name_Track
# Name_PlayList
# 90’s Music                        1477
# Brazilian Music                     39
# Classical                           75
# Classical 101 - Deep Cuts           25
# Classical 101 - Next Steps          25
# Classical 101 - The Basics          25
# Grunge                              15
# Heavy Metal Classic                 26
# Music                             6580
# Music Videos                         1
# On-The-Go 1                          1
# TV Shows                           426

# %% [markdown]
# ### 16. Provide a query that shows all the Tracks, but displays no IDs. The resultant table should include the Album name, Media type and Genre.

# %%
chinook.track.merge(chinook.album, on='AlbumId', how='inner').merge(chinook.mediatype, on='MediaTypeId', how='inner', suffixes=('_Track', '_Media')).merge(chinook.genre, on='GenreId', how='inner', suffixes=('_Track', '_Genre'))[['Title', 'Name_Media', 'Name']]
# Out:
#                                       Title                   Name_Media  \
# 0     For Those About To Rock We Salute You              MPEG audio file
# 1     For Those About To Rock We Salute You              MPEG audio file
# 2     For Those About To Rock We Salute You              MPEG audio file
# 3     For Those About To Rock We Salute You              MPEG audio file
# 4     For Those About To Rock We Salute You              MPEG audio file
# ...                                     ...                          ...
# 3498                   The Office, Season 3  Protected MPEG-4 video file
# 3499                   The Office, Season 3  Protected MPEG-4 video file
# 3500                   The Office, Season 3  Protected MPEG-4 video file
# 3501                   The Office, Season 3  Protected MPEG-4 video file
# 3502                   The Office, Season 3  Protected MPEG-4 video file
#
#         Name
# 0       Rock
# 1       Rock
# 2       Rock
# 3       Rock
# 4       Rock
# ...

# %% [markdown]
# ### 17. Provide a query that shows all Invoices but includes the # of invoice line items.

# %%
x_df = chinook.invoiceline.groupby('InvoiceId')['InvoiceLineId'].count().reset_index()

# %%
chinook.invoice.merge(x_df, on='InvoiceId', how='inner')
# Out:
#      InvoiceId  CustomerId InvoiceDate  \
# 0            1           2  2009-01-01
# 1            2           4  2009-01-02
# 2            3           8  2009-01-03
# 3            4          14  2009-01-06
# 4            5          23  2009-01-11
# ..         ...         ...         ...
# 407        408          25  2013-12-05
# 408        409          29  2013-12-06
# 409        410          35  2013-12-09
# 410        411          44  2013-12-14
# 411        412          58  2013-12-22
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          ---
# 1                            Ullevålsveien 14        Oslo          ---
# 2                             Grétrystraat 63    Brussels          ---
# 3                              8210 111 ST NW    Edmonton           AB
# 4                             69 Salem Street      Boston           MA
# ...

# %% [markdown]
# ### 18. Provide a query that shows total sales made by each sales agent.

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
pd.DataFrame(chinook.employee.merge(ic_df, left_on='EmployeeId' , right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Invoice')).groupby(['FirstName_Employee', 'LastName_Employee'])['Total'].sum()).reset_index()
# Out:
#   FirstName_Employee LastName_Employee   Total
# 0               Jane           Peacock  833.04
# 1           Margaret              Park  775.40
# 2              Steve           Johnson  720.16

# %% [markdown]
# ### 19. Which sales agent made the most in sales in 2009?

# %%
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
x_df = pd.DataFrame(chinook.employee.merge(ic_df, left_on='EmployeeId' , right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Invoice')).groupby(['InvoiceYear', 'FirstName_Employee', 'LastName_Employee'])['Total'].sum()).reset_index()

# %%
x_df = x_df[x_df['InvoiceYear'] == 2009]
x_df[x_df['Total'] == x_df.Total.max()][['FirstName_Employee', 'LastName_Employee']]
# Out:
#   FirstName_Employee LastName_Employee
# 2              Steve           Johnson

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)

# %% [markdown]
# ### 20. Which sales agent made the most in sales in 2010?

# %%
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
x_df = pd.DataFrame(chinook.employee.merge(ic_df, left_on='EmployeeId' , right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Invoice')).groupby(['InvoiceYear', 'FirstName_Employee', 'LastName_Employee'])['Total'].sum()).reset_index()

# %%
x_df = x_df[x_df['InvoiceYear'] == 2010]
x_df[x_df['Total'] == x_df.Total.max()][['FirstName_Employee', 'LastName_Employee']]
# Out:
#   FirstName_Employee LastName_Employee
# 3               Jane           Peacock

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)

# %% [markdown]
# ### 21. Which sales agent made the most in sales over all?

# %%
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
x_df = pd.DataFrame(chinook.employee.merge(ic_df, left_on='EmployeeId' , right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Invoice')).groupby(['InvoiceYear', 'FirstName_Employee', 'LastName_Employee'])['Total'].sum()).reset_index()

# %%
x_df[x_df['Total'] == x_df.Total.max()][['FirstName_Employee', 'LastName_Employee']]
# Out:
#   FirstName_Employee LastName_Employee
# 3               Jane           Peacock

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)

# %% [markdown]
# ### 22. Provide a query that shows the # of customers assigned to each sales agent.

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
pd.DataFrame(chinook.employee.merge(ic_df, left_on='EmployeeId' , right_on='SupportRepId', how='inner', suffixes=('_Employee', '_Invoice')).groupby(['FirstName_Employee', 'LastName_Employee'])['CustomerId'].count()).reset_index()
# Out:
#   FirstName_Employee LastName_Employee  CustomerId
# 0               Jane           Peacock         146
# 1           Margaret              Park         140
# 2              Steve           Johnson         126

# %% [markdown]
# ### 23. Provide a query that shows the total sales per country. Which country's customers spent the most?

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner')

# %%
x_df = pd.DataFrame(chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner').groupby('BillingCountry')['Total'].sum()).reset_index()

# %%
x_df[x_df['Total'] == x_df['Total'].max()]
# Out:
#    BillingCountry   Total
# 22            USA  523.06

# %% [markdown]
# ### 24. Provide a query that shows the most purchased track of 2013.

# %%
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
ic_df = chinook.customer.merge(chinook.invoice, on='CustomerId', how='inner', suffixes=('_Customer', '_Invoice'))

# %%
il_df = chinook.invoiceline.merge(ic_df, on='InvoiceId', how='inner', suffixes=('_Invoicel', '_Invoice'))
il_df = il_df[['InvoiceYear', 'TrackId', 'Total']]

# %%
x_df = chinook.track.merge(il_df, on='TrackId', how='inner', suffixes=('_Track', '_Invoicel')).groupby(['InvoiceYear', 'Name']).sum().reset_index()

# %%
x_df = x_df[x_df['InvoiceYear'] == 2013]
pd.DataFrame(x_df[x_df['Total'] == x_df.Total.max()]['Name'])
# Out:
#           Name
# 1873  Eruption

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)

# %% [markdown]
# ### 25. Provide a query that shows the top 5 most purchased tracks over all.

# %%
chinook.invoice['InvoiceYear'] = pd.to_datetime(chinook.invoice.InvoiceDate)
chinook.invoice['InvoiceYear'] = chinook.invoice.InvoiceYear.dt.year

# %%
il_df = chinook.invoiceline.merge(ic_df, on='InvoiceId', how='inner')
il_df = il_df[['InvoiceYear', 'TrackId', 'Total']]

# %%
x_df = chinook.track.merge(il_df, on='TrackId', how='inner', suffixes=('_Track', '_Invoicel')).groupby(['InvoiceYear', 'Name']).sum().reset_index()

# %%
pd.DataFrame(x_df.sort_values(ascending=False, by='Total')['Name'].head(5))
# Out:
#                          Name
# 18                     Animal
# 1602                    Polly
# 378   The Number Of The Beast
# 1873                 Eruption
# 2136                 The Moth

# %%
chinook.invoice.drop('InvoiceYear', axis=1, inplace=True)

# %% [markdown]
# ### 26. Provide a query that shows the top 3 best selling artists.

# %%
il_df = chinook.invoiceline.merge(ic_df, on='InvoiceId', how='inner')
il_df = il_df[['TrackId', 'Total']]

# %%
tl_df = chinook.track.merge(il_df, on='TrackId', how='inner')
tl_df = tl_df[['TrackId', 'Total', 'AlbumId']]

# %%
a_df = chinook.album.merge(chinook.artist, on='ArtistId', how='inner')
a_df = a_df[['AlbumId', 'Name']]

# %%
x_df = tl_df.merge(a_df, on='AlbumId', how='inner', suffixes=('_Track', '_Artist')).groupby('Name').sum().reset_index()

# %%
pd.DataFrame(x_df.sort_values(ascending=False, by='Total')['Name'].head(3))
# Out:
#             Name
# 69   Iron Maiden
# 156           U2
# 85          Lost

# %% [markdown]
# ### 27. Provide a query that shows the most purchased Media Type.

# %%
il_df = chinook.invoiceline.merge(ic_df, on='InvoiceId', how='inner')
il_df = il_df[['TrackId', 'Total']]

# %%
mt_df = chinook.mediatype.merge(chinook.track, on='MediaTypeId', how='inner', suffixes=('_Media', '_Track'))
mt_df = mt_df[['TrackId', 'Name_Media']]

# %%
x_df = mt_df.merge(il_df, on='TrackId', how='inner').groupby('Name_Media').sum().reset_index()

# %%
pd.DataFrame(x_df.sort_values(ascending=False, by='Total')['Name_Media'].head(1))
# Out:
#         Name_Media
# 1  MPEG audio file

# %% [markdown]
# #                                                         تمت بحمد الله
